# %%
pip install flickrapi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
BLESS UP THIS CODE WORKS: https://fivequestionz.home.blog/2020/07/30/how-to-map-the-photo-location-of-flickr-using-python-and-qgis/

# %%
from flickrapi import FlickrAPI
from urllib.request import urlretrieve
import os, time, sys
import json
import pandas as pd
import calendar

## Add your API Key and secret of Flickr
key = 'f6846300a3958b5cbec84b1dc41fd6d4'
secret = '1dcabc0d5db8270e'

# Span to access the flickr server
wait_time = 1

output_json = 'Flickr_data_2010_19'
 ## Please change the output file name

keyword = sys.argv[1]

photos = []
l = 0
##Loop start
n= [1,2,3,1,2,3,1,2,3,1,2,3,1,2,3,1,2,3,1,2,3,1,2,3,1,2,3,1,2,3,1,2,3,1,2,3]
for y in [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]: ## 10 years. You can change the years to collect photos from Flickr.

    for k in [1,1,1,2,2,2,3,3,3,4,4,4,5,5,5,6,6,6,7,7,7,8,8,8,9,9,9,10,10,10,11,11,11,12,12,12]:
        m = k
        l = l+1
        print(l)
        
        days = calendar.monthrange(y,m)[1]
        
        if n[l-1] == 3:
            min_taken_date = str(y) + '-' + str(m) + '-21'
            max_taken_date = str(y) + '-' + str(m) + '-' + str(days)
            #reset I for the next year
            if m == 12:
                l = 0
        elif n[l-1] ==2:
            min_taken_date = str(y) + '-' + str(m) + '-11'
            max_taken_date = str(y) + '-' + str(m) + '-20'
        elif n[l-1] ==1:
            min_taken_date = str(y) + '-' + str(m) + '-01'
            max_taken_date = str(y) + '-' + str(m) + '-10'
            
        print(n[l-1])
        print(min_taken_date)
        print(max_taken_date)
        
        # connecting to Flickr
        flickr = FlickrAPI(key, secret, format='parsed-json')
        
        i = 1
        while True:
            result = flickr.photos.search(
                #text = 'your keyword',    #keyword change
                per_page = 400,            #number of data per page
                has_geo = 1,               #Photo that has geo location
                min_taken_date = min_taken_date, 
                max_taken_date = max_taken_date,
                bbox = '-3.262659,55.909393,-3.094775,55.997397',
 #Please change the here for your study area in the order. LonLL, LatLL, LonUR, LatUR. LL:Lower Left corner, UR:Upper Right corner
                media = 'photos',         # collecting photos without video
                sort =  'date-taken-desc',       # collecting photos from latest
                privacy_filter =1,
                safe_search = 1,          #  photos without violence
                accuracy = [15,16],
                extras = 'geo,url_n,date_taken,tags',
                page = i
            )

            # export result
            #photos = ChainMap(photos, result['photos'])
            #photos = result['photos']
            j = result['photos']
            
            print('total_photo', j['total'])
            print('Current_pages', i)
            
            photos += j[ 'photo']

            #you can download up to 4000 photos in one query.
            if i > 10 :
                print('Your query has been exceeded the limit of photos.4000 photos' + str(i))
                break
            elif i >= j['pages'] :
                break
            i += 1
            
# export as Json format
d = json.dumps(photos, sort_keys = True, indent = 2)
#print(d)
fp = open(output_json+str(y)+'.json', 'w' )
fp.write( d )
fp.close()

# export as csv
df = pd.read_json (d)
df.to_csv(output_json+str(y)+'.csv', encoding='utf-8')
# Out:
# 1
# 1
# 2010-1-01
# 2010-1-10
# total_photo 104
# Current_pages 1
# 2
# 2
# 2010-1-11
# 2010-1-20
# total_photo 110
# Current_pages 1
# 3
# 3
# 2010-1-21
# 2010-1-31
# total_photo 96
# Current_pages 1
# 4
# 1
# 2010-2-01
# 2010-2-10
# total_photo 81
# Current_pages 1
# 5
# 2
# 2010-2-11
# 2010-2-20
# total_photo 145
# Current_pages 1
# 6
# 3
# 2010-2-21
# 2010-2-28
# total_photo 47
# Current_pages 1
# 7
# 1
# 2010-3-01
# 2010-3-10
# total_photo 89
# Current_pages 1
# 8
# 2
# 2010-3-11
# 2010-3-20
# total_photo 136
# Current_pages 1
# 9
# 3
# 2010-3-21
# 2010-3-31
# total_photo 115
# Current_pages 1
# 10
# 1
# 2010-4-01
# 2010-4-10
# total_photo 127
# Current_pages 1
# 11
# 2
# 2010-4-11
# 2010-4-20
# total_photo 146
# Current_pages 1
# 12
# 3
# 2010-4-21
# 2010-4-30
# total_photo 66
# Current_pages 1
# 13
# 1
# 2010-5-01
# 2010-5-10
# total_photo 163
# Current_pages 1
# 14
# 2
# 2010-5-11
# 2010-5-20
# total_photo 112
# Current_pages 1
# 15
# 3
# 2010-5-21
# 2010-5-31
# ...

# %%
df = pd.read_json("Flickr_data_2010_192019.json")
df.to_csv('Flickr_data_2010_2019.csv', encoding='utf-8')

# %%
###COLLECTION ONLY FOR 2017
#ENSURE THE CSV NAME IS CHANGED PRIOR TO RUNNING CODE!!!!

import flickrapi
import os
import datetime
import time

## Only needed to explore the xml tree
# import xml 

## API key and secret provided by Flickr
api_key = 'f6846300a3958b5cbec84b1dc41fd6d4'
secret = '1dcabc0d5db8270e'

## Approximate geographic coordinates of the administrational boundaries of the city of Edinburgh
boundaries = '-3.262659,55.909393,-3.094775,55.997397'

## Counter for the ID column required by GIS software
id_count = 1

## Creation of an editable csv file and its top row
csv = open('flickr_data_2010.csv', mode='a')
if(os.stat('flickr_data_2010.csv').st_size == 0):
    csv.write('ID,Photo_ID,Lat,Lon,Tags,Coordinates,Date_unix, Date, URL \n')

## Authentication of the Flickr API
flickr = flickrapi.FlickrAPI(api_key, secret)

## Page counter
page_number = 1

## Only needed to explore the xml tree
# test_list = flickr.photos_search(max_upload_date = '2020-07-09 23:59:59',min_upload_date = '2020-01-15 0:00:00',tags = 'Köln',bbox = boundaries,has_geo = '1',page = 1,extras = 'views',per_page = '250')
# xml.etree.ElementTree.dump(test_list)

## While loop keeps running until page 16 is reached. The total number of pages for the wanted search query is 452.
## However, Flickr only returns a number of photos equivalent to 16 pages of 250 results.
## At this point, the code is reiterated until the maximum number of pages is reached.
while page_number < 7:
    
    ## Flickr search for the geographic boundaries of Edinburgh.
    photo_list = flickr.photos_search(max_upload_date = '2010-12-31 23:59:59',
                                      min_upload_date = '2017-01-01 00:00:00', 
                                      bbox = boundaries,
                                      has_geo = '1',
                                      page = page_number,
                                      per_page = '200',## 250 maximum allowed photos per page for bbox-delimited requests
                                      privacy_filter=1,
                                      accuracy=16,
                                      content_type=1,
                                      extras='date_taken,geo, tags') 
    
    ## For loop keeps running as long as there are photos on a page
    for photo in photo_list[0]:
        ## extraction of latitude and longitude data from the search results
        geodata = flickr.photos_geo_getLocation(photo_id = photo.attrib['id'])
        lat = geodata[0][0].attrib['latitude']
        lon = geodata[0][0].attrib['longitude']
        
        ## extraction of tags
        tags = photo.get('tags')

        ## extraction and conversion of upload dates
        photo_info = flickr.photos.getInfo(photo_id = photo.attrib['id'])
        date_unix = int(photo_info[0][4].attrib['posted'])
        date = datetime.datetime.utcfromtimestamp(date_unix).strftime('%Y-%m-%d %H:%M:%S')
        url = 'https://www.flickr.com/photos/' + photo.attrib['owner'] + '/' + photo.attrib['id']

        
        
        ## the csv is filled with the acquired information
        
        csv.write('%s,%s,%s,%s,%s,%s,%s,%s \n' % (id_count,
                                                  photo.attrib['id'],
                                                  lat,
                                                  lon,
                                                  tags,
                                                  date_unix,
                                                  date,
                                                  url))
        id_count += 1
        ## 1 second wait time between calls to prevent error code 500
        #time.sleep(60)
    ## Turns the page
    page_number += 1

## Total number of photos searched
#print(sum(1 for line in open(flickr_data.csv))-1)

#csv.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_703/3803501588.py in <module>
#      63
#      64         ## extraction and conversion of upload dates
# ---> 65         photo_info = flickr.photos.getInfo(photo_id = photo.attrib['id'])
#      66         date_unix = int(photo_info[0][4].attrib['posted'])
#      67         date = datetime.datetime.utcfromtimestamp(date_unix).strftime('%Y-%m-%d %H:%M:%S')
#
# /opt/conda/lib/python3.9/site-packages/flickrapi/call_builder.py in __call__(self, **kwargs)
#      36
#      37     def __call__(self, **kwargs):
# ---> 38         return self.flickrapi_object.do_flickr_call(self.method_name, **kwargs)
#      39
#      40 if __name__ == '__main__':
#
# /opt/conda/lib/python3.9/site-packages/flickrapi/core.py in do_flickr_call(self, _method_name, timeout, **kwargs)
#     332         LOG.info('Calling %s', defaults)
#     333
# ...

# %%
###COLLECTION ONLY FOR 2017
#ENSURE THE CSV NAME IS CHANGED PRIOR TO RUNNING CODE!!!!

import flickrapi
import os
import datetime
import time
import json

## Only needed to explore the xml tree
# import xml 

## API key and secret provided by Flickr
api_key = 'f6846300a3958b5cbec84b1dc41fd6d4'
secret = '1dcabc0d5db8270e'

## Approximate geographic coordinates of the administrational boundaries of the city of Edinburgh
boundaries = '-3.512575,55.705906,-2.830736,56.102752'

## Counter for the ID column required by GIS software
id_count = 1

## Creation of an editable csv file and its top row
#csv = open('flickr_data_2017_12.csv', mode='a')
#if(os.stat('flickr_data_2017_12.csv').st_size == 0):
 #   csv.write('ID,Photo_ID,Lat,Lon,Tags,Coordinates,Date_unix, Date, URL \n')

## Authentication of the Flickr API
flickr = flickrapi.FlickrAPI(api_key, secret,format='parsed-json')

## Page counter
page_number = 1

## Only needed to explore the xml tree
# test_list = flickr.photos_search(max_upload_date = '2020-07-09 23:59:59',min_upload_date = '2020-01-15 0:00:00',tags = 'Köln',bbox = boundaries,has_geo = '1',page = 1,extras = 'views',per_page = '250')
# xml.etree.ElementTree.dump(test_list)

## While loop keeps running until page 16 is reached. The total number of pages for the wanted search query is 452.
## However, Flickr only returns a number of photos equivalent to 16 pages of 250 results.
## At this point, the code is reiterated until the maximum number of pages is reached.
while page_number < 7:
    
    ## Flickr search for the geographic boundaries of Edinburgh.
    photo_list = flickr.photos_search(max_upload_date = '2017-12-02 15:38:36',
                                      min_upload_date = '2017-12-01 00:00:00', 
                                      bbox = boundaries,
                                      has_geo = '1',
                                      page = page_number,
                                      per_page = '200',## 250 maximum allowed photos per page for bbox-delimited requests
                                      privacy_filter=1,
                                      accuracy=16,
                                      content_type=1,
                                      extras='date_taken,geo, tags')
 
    for photo in photo_list:
            ## extraction of latitude and longitude data from the search results
            geodata = flickr.photos_geo_getLocation(photo_id = photo.attrib['id'])
            lat = geodata[0][0].attrib['latitude']
            lon = geodata[0][0].attrib['longitude']

            ## extraction of tags
            tags = photo.get('tags')

            ## extraction and conversion of upload dates
            photo_info = flickr.photos.getInfo(photo_id = photo.attrib['id'])
            date_unix = int(photo_info[0][4].attrib['posted'])
            date = datetime.datetime.utcfromtimestamp(date_unix).strftime('%Y-%m-%d %H:%M:%S')
            url = 'https://www.flickr.com/photos/' + photo.attrib['owner'] + '/' + photo.attrib['id']

    
    with open('2017_12data.json', 'a') as f:
        json.dump((id_count,lat,lon,tags,date_unix,date,url),f)
        id_count += 1
    ## 1 second wait time between calls to prevent error code 500
    #time.sleep(60)
## Turns the page
        page_number += 1

## Total number of photos searched
#print(sum(1 for line in open(flickr_data.csv))-1)

#ISSUE: NOT JSON SERIALISABLE
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_138/432768039.py in <module>
#      55     for photo in photo_list:
#      56             ## extraction of latitude and longitude data from the search results
# ---> 57             geodata = flickr.photos_geo_getLocation(photo_id = photo.attrib['id'])
#      58             lat = geodata[0][0].attrib['latitude']
#      59             lon = geodata[0][0].attrib['longitude']
#
# AttributeError: 'str' object has no attribute 'attrib'

# %%
import datetime
import time
import json

## Only needed to explore the xml tree
# import xml 

## API key and secret provided by Flickr
api_key = 'f6846300a3958b5cbec84b1dc41fd6d4'
secret = '1dcabc0d5db8270e'

## Approximate geographic coordinates of the administrational boundaries of the city of Edinburgh
boundaries = '-3.262659,55.909393,-3.094775,55.997397'
#'-3.512575,55.705906,-2.830736,56.102752'
#shaded out is the bbox for whole of edi

## Counter for the ID column required by GIS software
id_count = 1

## Creation of an editable csv file and its top row
#csv = open('flickr_data_2017_12.csv', mode='a')
#if(os.stat('flickr_data_2017_12.csv').st_size == 0):
 #   csv.write('ID,Photo_ID,Lat,Lon,Tags,Coordinates,Date_unix, Date, URL \n')

## Authentication of the Flickr API
flickr = flickrapi.FlickrAPI(api_key, secret)

## Page counter
page_number = 1

## Only needed to explore the xml tree
# test_list = flickr.photos_search(max_upload_date = '2020-07-09 23:59:59',min_upload_date = '2020-01-15 0:00:00',tags = 'Köln',bbox = boundaries,has_geo = '1',page = 1,extras = 'views',per_page = '250')
# xml.etree.ElementTree.dump(test_list)

## While loop keeps running until page 16 is reached. The total number of pages for the wanted search query is 452.
## However, Flickr only returns a number of photos equivalent to 16 pages of 250 results.
## At this point, the code is reiterated until the maximum number of pages is reached.
while page_number < 7:
    
    ## Flickr search for the geographic boundaries of Edinburgh.
    photo_list = flickr.photos_search(max_upload_date = '2010-12-31 23:59:59',
                                      min_upload_date = '2010-01-01 00:00:00', 
                                      bbox = boundaries,
                                      has_geo = '1',
                                      page = page_number,
                                      per_page = '200',## 250 maximum allowed photos per page for bbox-delimited requests
                                      privacy_filter=1,
                                      accuracy=[15,16],
                                      content_type=1,
                                      extras='date_taken,geo, tags')
    for photo in photo_list[0]:
        print(photo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_703/2284408486.py in <module>
#      24
#      25 ## Authentication of the Flickr API
# ---> 26 flickr = flickrapi.FlickrAPI(api_key, secret)
#      27
#      28 ## Page counter
#
# NameError: name 'flickrapi' is not defined
